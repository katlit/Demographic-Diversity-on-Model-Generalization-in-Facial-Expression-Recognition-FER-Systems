# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from urllib.parse import urlparse

# %%
# Set global font size
plt.rcParams.update({
    'font.size': 16,  # Adjust this to your preferred size
    'axes.titlesize': 18,
    'axes.labelsize': 16,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14
})

# %%
file_path = '../1_scraping/FullText_ALL.csv'
FullText_df = pd.read_csv(file_path)
FullText_df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  10 Automated Face Analysis for Affective Compu...
# 1           1  3D facial expression recognition based on auto...
# 2           2  3D facial expression recognition based on prim...
# 3           3  3D facial expression recognition based on prop...
# 4           4  3D facial expression recognition using SIFT de...
#
#                                              Authors  Year  Cited By  \
# 0                       ['JF Cohn', 'F De la Torre']  2015       170
# 1                             ['H Tang', 'TS Huang']  2008       205
# 2              ['J Wang', 'L Yin', 'X Wei', 'Y Sun']  2006       440
# 3                             ['H Tang', 'TS Huang']  2008       153
# 4  ['S Berretti', 'B Ben Amor', 'M Daoudi', 'A De...  2011       184
#
#                              Detected_Dataset  \
# 0                    Affective Faces Database
# 1  Binghamton University 3D Facial Expression
# 2  Binghamton University 3D Facial Expression
# 3  Binghamton University 3D Facial Expression
# 4  Binghamton University 3D Facial Expression
#
#                                       Detected_Topic  \
# 0                                         classifier
# 1  classification, classifier, facial expression ...
# 2                      facial expression recognition
# 3  classification, classifier, facial expression ...
# 4  classification, classifier, facial expression ...
#
#                                             Abstract  \
# 0  Differences in manual coding between databases...
# 1  facial expression recognition from 3D facial s...
# 2  expressions using 3D facial expression range d...
# 3  Binghamton University have recently constructe...
# 4  at the Binghamton University (BU-3DFE database...
#
#                                           Journal  \
# 0              The Oxford handbook of affective …
# 1  … on computer vision and pattern recognition …
# 2             … Vision and Pattern Recognition  …
# 3       … on Automatic Face & Gesture Recognition
# 4                             The Visual Computer
#
#                                                  URL  \
# 0  https://academic.oup.com/edited-volume/28057/c...
# 1       https://ieeexplore.ieee.org/document/4563052
# 2       https://ieeexplore.ieee.org/document/1640921
# 3       https://ieeexplore.ieee.org/document/4813304
# 4  https://www.researchgate.net/publication/22006...
#
#                                            Full_Text
# 0                                                NaN
# 1  3D Facial Expression Recognition Based on Auto...
# 2  3D Facial Expression Recognition Based on Prim...
# 3  3DFacial Expr ession Recognition Based onPrope...
# 4                                                NaN

# %%
df = FullText_df.copy()

def clean_text(text):
    # Return NaN if text is empty or placeholder
    if text is np.nan or text == "Nothing found":
        return np.nan

    # Remove common metadata patterns and unwanted sections
    # Adjust regex patterns based on your files' content
    text = re.sub(r'\b(References|Cited by|Acknowledgments|Table of Contents|Outline|Figure \d+|Table \d+|DOI: .*)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'##?\s?Title:.*?\n', '', text)  # Remove lines that start with '## Title:'
    text = re.sub(r'https?://\S+|www\.\S+', '', text)  # Remove URLs

    # Remove special characters and multiple spaces
    text = re.sub(r'\n+', ' ', text)  # Replace newlines with space
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = re.sub(r'\s*Figure\s*\d+\s*', '', text)  # Remove figure references
    text = re.sub(r'\s*Table\s*\d+\s*', '', text)  # Remove table references

    # Trim any leading or trailing whitespace
    text = text.strip()
    
    # Remove line breaks and excessive whitespace
    text = re.sub(r'\s+', ' ', text)

    return text

# Apply the cleaning function to the Full_Text column
df['Full_Text'] = df['Full_Text'].apply(clean_text)

# Display the cleaned texts
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  10 Automated Face Analysis for Affective Compu...
# 1           1  3D facial expression recognition based on auto...
# 2           2  3D facial expression recognition based on prim...
# 3           3  3D facial expression recognition based on prop...
# 4           4  3D facial expression recognition using SIFT de...
#
#                                              Authors  Year  Cited By  \
# 0                       ['JF Cohn', 'F De la Torre']  2015       170
# 1                             ['H Tang', 'TS Huang']  2008       205
# 2              ['J Wang', 'L Yin', 'X Wei', 'Y Sun']  2006       440
# 3                             ['H Tang', 'TS Huang']  2008       153
# 4  ['S Berretti', 'B Ben Amor', 'M Daoudi', 'A De...  2011       184
#
#                              Detected_Dataset  \
# 0                    Affective Faces Database
# 1  Binghamton University 3D Facial Expression
# 2  Binghamton University 3D Facial Expression
# 3  Binghamton University 3D Facial Expression
# 4  Binghamton University 3D Facial Expression
#
#                                       Detected_Topic  \
# 0                                         classifier
# 1  classification, classifier, facial expression ...
# 2                      facial expression recognition
# 3  classification, classifier, facial expression ...
# 4  classification, classifier, facial expression ...
#
#                                             Abstract  \
# 0  Differences in manual coding between databases...
# 1  facial expression recognition from 3D facial s...
# 2  expressions using 3D facial expression range d...
# 3  Binghamton University have recently constructe...
# 4  at the Binghamton University (BU-3DFE database...
#
#                                           Journal  \
# 0              The Oxford handbook of affective …
# 1  … on computer vision and pattern recognition …
# 2             … Vision and Pattern Recognition  …
# 3       … on Automatic Face & Gesture Recognition
# 4                             The Visual Computer
#
#                                                  URL  \
# 0  https://academic.oup.com/edited-volume/28057/c...
# 1       https://ieeexplore.ieee.org/document/4563052
# 2       https://ieeexplore.ieee.org/document/1640921
# 3       https://ieeexplore.ieee.org/document/4813304
# 4  https://www.researchgate.net/publication/22006...
#
#                                            Full_Text
# 0                                                NaN
# 1  3D Facial Expression Recognition Based on Auto...
# 2  3D Facial Expression Recognition Based on Prim...
# 3  3DFacial Expr ession Recognition Based onPrope...
# 4                                                NaN

# %%
df_no_nan = df.dropna(subset=['Full_Text'])
df_no_nan['Text_Length'] = df_no_nan['Full_Text'].apply(len)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df_no_nan.index, df_no_nan['Text_Length'], marker='o', linestyle='-')
plt.title('Length of Full Text Entries (Non-NaN Only)')
plt.xlabel('Row Index')
plt.ylabel('Text Length (in characters)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\liter\AppData\Local\Temp\ipykernel_20636\468863222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_nan['Text_Length'] = df_no_nan['Full_Text'].apply(len)

# %%
# Filter rows in df_no_nan where the length of 'Full_Text' is zero
empty_text_rows = df_no_nan[df_no_nan['Text_Length'] != 0]

# Drop the column 'Unnamed: 0'
empty_text_rows = empty_text_rows.drop(columns='Unnamed: 0', inplace=False)

# Reset the index
empty_text_rows = empty_text_rows.reset_index(drop=True, inplace=False)
empty_text_rows
# Out:
#                                                 Title  \
# 0   3D facial expression recognition based on auto...
# 1   3D facial expression recognition based on prim...
# 2   3D facial expression recognition based on prop...
# 3   A 3D facial expression database for facial beh...
# 4   A brief review of facial emotion recognition b...
# ..                                                ...
# 91  Recognizing facial expression: machine learnin...
# 92  Reliable crowdsourcing and deep locality-prese...
# 93  Shape analysis of local facial patches for 3D ...
# 94  Single sample face recognition via learning de...
# 95  Spatio-temporal convolutional features with ne...
#
#                                               Authors  Year  Cited By  \
# 0                              ['H Tang', 'TS Huang']  2008       205
# 1               ['J Wang', 'L Yin', 'X Wei', 'Y Sun']  2006       440
# 2                              ['H Tang', 'TS Huang']  2008       153
# 3               ['L Yin', 'X Wei', 'Y Sun', 'J Wang']  2006      1631
# 4                                           ['BC Ko']  2018       762
# ..                                                ...   ...       ...
# 91         ['MS Bartlett', 'G Littlewort', 'M Frank']  2005       912
# 92                        ['S Li', 'W Deng', 'JP Du']  2017      1700
# 93  ['A Maalej', 'BB Amor', 'M Daoudi', 'A Srivast...  2011       107
# 94              ['S Gao', 'Y Zhang', 'K Jia', 'J Lu']  2015       265
# 95               ['Z Yu', 'G Liu', 'Q Liu', 'J Deng']  2018       158
#
#                               Detected_Dataset  \
# 0   Binghamton University 3D Facial Expression
# 1   Binghamton University 3D Facial Expression
# 2   Binghamton University 3D Facial Expression
# 3   Binghamton University 3D Facial Expression
# 4           Facial Expression Recognition 2013
# ..                                         ...
# 91                        Extended Cohn-Kanade
# 92                      Expression in-the-Wild
# 93  Binghamton University 3D Facial Expression
# 94                       Toronto Face Database
# 95                                  Oulu-CASIA
#
#                                        Detected_Topic  \
# 0   classification, classifier, facial expression ...
# 1                       facial expression recognition
# 2   classification, classifier, facial expression ...
# 3   classification, classifier, deep learning, fac...
# 4                       facial expression recognition
# ..                                                ...
# 91                                   machine learning
# 92  CNN, classification, classifier, deep learning...
# 93  classification, classifier, deep learning, fac...
# 94                    deep learning, machine learning
# 95                                     classification
#
#                                              Abstract  \
# 0   facial expression recognition from 3D facial s...
# 1   expressions using 3D facial expression range d...
# 2   Binghamton University have recently constructe...
# 3   3D: Critical Issues and Limitations of 2D (1) ...
# 4   recognition and facial expression recognition....
# ..                                                ...
# 91  We first report performance for generalization...
# 92  For all we know, RAF-DB is the first database ...
# 93  ► We address the 3D facial expression recognit...
# 94  based deep neural networks, and driven by the ...
# 95  Oulu-CASIA: We also consider for experiments t...
#
#                                            Journal  \
# 0   … on computer vision and pattern recognition …
# 1              … Vision and Pattern Recognition  …
# 2        … on Automatic Face & Gesture Recognition
# 3                     … and gesture recognition  …
# 4                                          sensors
# ..                                             ...
# 91                            2005 IEEE Computer …
# 92          … of the IEEE conference on computer …
# 93                             Pattern Recognition
# 94                          IEEE transactions on …
# 95                                  Neurocomputing
#
#                                                   URL  \
# 0        https://ieeexplore.ieee.org/document/4563052
# 1        https://ieeexplore.ieee.org/document/1640921
# 2        https://ieeexplore.ieee.org/document/4813304
# 3        https://ieeexplore.ieee.org/document/1613022
# 4             https://www.mdpi.com/1424-8220/18/2/401
# ..                                                ...
# 91  https://ieeexplore.ieee.org/document/1467492/1000
# 92       https://ieeexplore.ieee.org/document/8099760
# 93  https://www.sciencedirect.com/science/article/...
# 94       https://ieeexplore.ieee.org/document/7124463
# 95  https://www.sciencedirect.com/science/article/...
#
#                                             Full_Text  Text_Length
# 0   3D Facial Expression Recognition Based on Auto...        14288
# 1   3D Facial Expression Recognition Based on Prim...        37039
# 2   3DFacial Expr ession Recognition Based onPrope...         8779
# 3   A 3D Facial Expression Database For Facial Beh...        30777
# 4   BREUER,KIMMEL:ADEEPLEARNINGPERSPECTIVEONFACIAL...        37571
# ..                                                ...          ...
# 91  1 Utilizing Deep Learning Towards Multi-modal ...        67526
# 92  Reliable Crowdsourcing and Deep Locality-Prese...        52231
# 93  expression recognition the features on this pa...         8165
# 94  2108 IEEE TRANSACTIONS ON INFORMATION FORENSIC...        61874
# 95  facial expression recognition the features on ...        32280
#
# [96 rows x 11 columns]

# %%
df_no_nan = df_no_nan.drop(['Unnamed: 0', 'Text_Length'], axis= 1)
df_no_nan.shape
# Out:
# (96, 10)

# %%
df_no_nan.columns
# Out:
# Index(['Title', 'Authors', 'Year', 'Cited By', 'Detected_Dataset',
#        'Detected_Topic', 'Abstract', 'Journal', 'URL', 'Full_Text'],
#       dtype='object')

# %%
df[df.duplicated(subset=['Title'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Authors, Year, Cited By, Detected_Dataset, Detected_Topic, Abstract, Journal, URL, Full_Text]
# Index: []

# %%
df.shape
# Out:
# (261, 11)

# %%
FullText_df.shape
# Import necessary libraries
import pandas as pd


# Assuming your DataFrame is named FullText_df and has a column named 'URL'

# Extract the main domain from each URL
FullText_df['Main_Webpage'] = FullText_df['URL'].apply(lambda x: urlparse(x).netloc if pd.notna(x) else 'Unknown')

# Count the occurrences of each domain
domain_counts = FullText_df['Main_Webpage'].value_counts()


print(len(domain_counts))
# Display the counts
print(domain_counts)

# If you want to save the counts to a CSV
domain_counts.to_csv("webpage_domain_counts.csv", header=["Count"])
# Out:
# 29
# Main_Webpage
# ieeexplore.ieee.org                    84
# arxiv.org                              41
# www.sciencedirect.com                  40
# link.springer.com                      22
# pubmed.ncbi.nlm.nih.gov                18
# dl.acm.org                             13
# www.mdpi.com                            8
# openaccess.thecvf.com                   6
# www.ncbi.nlm.nih.gov                    4
# www.researchgate.net                    4
# www.tandfonline.com                     2
# paperswithcode.com                      2
# www.computer.org                        1
# onlinelibrary.wiley.com                 1
# kdef.se                                 1
# citeseerx.ist.psu.edu                   1
# mug.ee.auth.gr                          1
# www.cs.cmu.edu                          1
# proceedings.mlr.press                   1
# academic.oup.com                        1
# www.utpjournals.press                   1
# github.com                              1
# ietresearch.onlinelibrary.wiley.com     1
# www.cedus.it                            1
# www.nature.com                          1
# iopscience.iop.org                      1
# journals.sagepub.com                    1
# journals.plos.org                       1
# www.cs.toronto.edu                      1
# Name: count, dtype: int64

# %%
df['Detected_Dataset'].unique()
# Out:
# array(['Affective Faces Database',
#        'Binghamton University 3D Facial Expression',
#        'Facial Expression Recognition 2013',
#        'Acted Facial Expressions In The Wild, Extended Cohn-Kanade, Static Facial Expression in the Wild',
#        'Affective Faces Database, MMI Facial Expression',
#        'Extended Cohn-Kanade', 'Japanese Female Facial Expression',
#        'Acted Facial Expressions In The Wild, Affective Faces Database, Static Facial Expression in the Wild',
#        'Binghamton University 3D Facial Expression, Facial Expression Recognition 2013, MMI Facial Expression',
#        'Toronto Face Database',
#        'Acted Facial Expressions In The Wild, Static Facial Expression in the Wild',
#        'Affective Faces Database, Expression in-the-Wild',
#        'CMU Multi-PIE, MMI Facial Expression',
#        'Extended Cohn-Kanade, Facial Expression Recognition 2013, Radboud Faces Database',
#        'Affective Faces Database, Radboud Faces Database',
#        'Expression in-the-Wild',
#        'Acted Facial Expressions In The Wild, Affective Faces Database',
#        'Acted Facial Expressions In The Wild, Affective Faces Database, Expression in-the-Wild, Static Facial Expression in the Wild',
#        'MMI Facial Expression',
#        'Acted Facial Expressions In The Wild, MMI Facial Expression',
#        'Affective Faces Database, Facial Expression Recognition 2013',
#        'Karolinska Directed Emotional Faces',
#        'Expression in-the-Wild, Static Facial Expression in the Wild',
#        'Acted Facial Expressions In The Wild',
#        'Affective Faces Database, Static Facial Expression in the Wild',
#        'Acted Facial Expressions In The Wild, Affective Faces Database, Binghamton University 3D Facial Expression, Facial Expression Recognition 2013, Japanese Female Facial Expression, MMI Facial Expression, Radboud Faces Database, Static Facial Expression in the Wild, Toronto Face Database',
#        'Affective Faces Database, Toronto Face Database',
#        'Acted Facial Expressions In The Wild, Facial Expression Recognition 2013',
#        'Affective Faces Database, Extended Cohn-Kanade, Facial Expression Recognition 2013, Japanese Female Facial Expression, Toronto Face Database',
#        'Extended Cohn-Kanade, Facial Expression Recognition 2013, MMI Facial Expression',
#        'Acted Facial Expressions In The Wild, Extended Cohn-Kanade, Toronto Face Database',
#        'Extended Cohn-Kanade, Facial Expression Recognition 2013',
#        'Acted Facial Expressions In The Wild, Expression in-the-Wild',
#        'Acted Facial Expressions In The Wild, Expression in-the-Wild, Static Facial Expression in the Wild',
#        'Extended Cohn-Kanade, Japanese Female Facial Expression',
#        'Facial Expression Recognition 2013, Japanese Female Facial Expression',
#        'Extended Cohn-Kanade, MMI Facial Expression',
#        'Affective Faces Database, Binghamton University 3D Facial Expression, Extended Cohn-Kanade, Japanese Female Facial Expression',
#        'Radboud Faces Database', 'Oulu-CASIA',
#        'Acted Facial Expressions In The Wild, Expression in-the-Wild, Facial Expression Recognition 2013, Static Facial Expression in the Wild',
#        'Japanese Female Facial Expression, Toronto Face Database',
#        'Affective Faces Database, Binghamton University 3D Facial Expression, Radboud Faces Database',
#        'Facial Expression Recognition 2013, Toronto Face Database',
#        'Facial Expression Recognition 2013, MMI Facial Expression',
#        'Affective Faces Database, Japanese Female Facial Expression',
#        'Acted Facial Expressions In The Wild, Extended Cohn-Kanade, Facial Expression Recognition 2013, Japanese Female Facial Expression, Radboud Faces Database',
#        'Binghamton University 3D Facial Expression, Facial Expression Recognition 2013',
#        'Binghamton University 3D Facial Expression, Facial Expression Recognition 2013, Japanese Female Facial Expression, MMI Facial Expression',
#        'Static Facial Expression in the Wild',
#        'Acted Facial Expressions In The Wild, Affective Faces Database, Facial Expression Recognition 2013, MMI Facial Expression, Static Facial Expression in the Wild, Toronto Face Database',
#        'Facial Expression Recognition 2013, Static Facial Expression in the Wild',
#        'Binghamton University 3D Facial Expression, Oulu-CASIA',
#        'Facial Expression Recognition 2013, MMI Facial Expression, Static Facial Expression in the Wild',
#        'Acted Facial Expressions In The Wild, CMU Multi-PIE, Facial Expression Recognition 2013, Static Facial Expression in the Wild, Toronto Face Database',
#        'CMU Multi-PIE, Toronto Face Database',
#        'Facial Expression Recognition 2013, MMI Facial Expression, Oulu-CASIA',
#        'CMU Multi-PIE',
#        'Binghamton University 3D Facial Expression, Facial Expression Recognition 2013, Toronto Face Database',
#        'Affective Faces Database, Karolinska Directed Emotional Faces',
#        'Acted Facial Expressions In The Wild, Affective Faces Database, Expression in-the-Wild',
#        'MMI Facial Expression, Static Facial Expression in the Wild, Toronto Face Database'],
#       dtype=object)

# %%
# Function to count and plot individual datasets
def plot_individual_datasets(df, column='Detected_Dataset', top_n=20, save_path='top_datasets.pdf'):
    # Split the column values by commas and flatten into a single list
    all_datasets = []
    df[column].dropna().apply(lambda x: all_datasets.extend(x.split(', ')))
    
    # Count occurrences of each dataset
    dataset_counts = Counter(all_datasets)
    most_common_datasets = dataset_counts.most_common(top_n)
    
    # Prepare data for plotting
    datasets, counts = zip(*most_common_datasets)
    
    # Plot the top detected datasets
    plt.figure(figsize=(10, 6))
    plt.barh(datasets, counts, color="gray", edgecolor="black")
    plt.title("Top Detected Datasets")
    plt.xlabel("Frequency")
    plt.ylabel("Dataset")
    plt.gca().invert_yaxis()  # To display the most frequent dataset at the top
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the plot to a PDF file
    plt.savefig(save_path, format='pdf', dpi=300, bbox_inches='tight')
    
    # Show the plot
    plt.show()

plot_individual_datasets(df, column='Detected_Dataset', top_n=10, save_path='top_detected_datasets.pdf')

# %%
# from the new paper: https://arxiv.org/abs/2410.22506

import pandas as pd

# Data for the table
data = {
    "Model": ["ResNet-50", "ResNet-50", "EfficientNet-B3", "XceptionNet", "Ensemble"],
    "Emotion Class": ["Happy", "Sad", "Fear", "Disgust", "Contempt"],
    "Accuracy (%)": [85.86, 67.00, 88.62, 91.47, 78.51],
    "Methodology": ["Hard-FER (Easy)", "AU-Based Classifier", "Binary Classifiers", "Binary Classifiers", "Binary Classifiers"]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("affectnet_accuracy.csv", index=False)

# %%
df
# Out:
#              Model Emotion Class  Accuracy (%)          Methodology
# 0        ResNet-50         Happy         85.86      Hard-FER (Easy)
# 1        ResNet-50           Sad         67.00  AU-Based Classifier
# 2  EfficientNet-B3          Fear         88.62   Binary Classifiers
# 3      XceptionNet       Disgust         91.47   Binary Classifiers
# 4         Ensemble      Contempt         78.51   Binary Classifiers

# %%
file_path = 'FER_Accuracy_Table.csv'
ACC_df = pd.read_csv(file_path)
ACC_df.head()
# Out:
#   Datasets               Method   Network Type Network Size Pre-processing  \
# 0      CK+     Ouellet 14 [110]  CNN (AlexNet)            -              -
# 1      CK+    Li et al. 15 [86]            RBM            4              -
# 2      CK+   Liu et al. 14 [13]         DBN CN            6             2m
# 3      CK+  Liu et al. 13 [137]    CNN, RBM CN            5              -
# 4      CK+  Liu et al. 15 [138]    CNN, RBM CN            5              -
#
#   Data Selection      Data Group Additional Classifier  \
# 0            V&J  the last frame                  LOSO
# 1            V&J               -                    IN
# 2              -               -               8 folds
# 3            V&J               -              10 folds
# 4            V&J               -              10 folds
#
#                 Performance (%)
# 0        SVM 7 classes†: (94.4)
# 1               6 classes: 96.8
# 2      AdaBoost 6 classes: 96.7
# 3  SVM 8 classes: 92.05 (87.67)
# 4         SVM 7 classes‡: 93.70

# %%
def extract_floats_as_accuracy(df, performance_column='Performance (%)', new_column='Accuracy'):
    # Extract only floating-point numbers (e.g., 94.4, 87.67)
    df[new_column] = df[performance_column].str.extract(r'(\d+\.\d+)').astype(float)
    return df

# Apply the function to your DataFrame
ACC_df = extract_floats_as_accuracy(ACC_df, performance_column='Performance (%)', new_column='Accuracy')
ACC_df.head()
# Out:
#   Datasets               Method   Network Type Network Size Pre-processing  \
# 0      CK+     Ouellet 14 [110]  CNN (AlexNet)            -              -
# 1      CK+    Li et al. 15 [86]            RBM            4              -
# 2      CK+   Liu et al. 14 [13]         DBN CN            6             2m
# 3      CK+  Liu et al. 13 [137]    CNN, RBM CN            5              -
# 4      CK+  Liu et al. 15 [138]    CNN, RBM CN            5              -
#
#   Data Selection      Data Group Additional Classifier  \
# 0            V&J  the last frame                  LOSO
# 1            V&J               -                    IN
# 2              -               -               8 folds
# 3            V&J               -              10 folds
# 4            V&J               -              10 folds
#
#                 Performance (%)  Accuracy
# 0        SVM 7 classes†: (94.4)     94.40
# 1               6 classes: 96.8     96.80
# 2      AdaBoost 6 classes: 96.7     96.70
# 3  SVM 8 classes: 92.05 (87.67)     92.05
# 4         SVM 7 classes‡: 93.70     93.70

# %%
ACC_df['Datasets'].unique()
# Out:
# array(['CK+', 'JAFFE', 'MMI', 'TFD', 'FER 2013', 'SFEW 2.0'], dtype=object)

# %%
new_df = df 

new_df['Datasets'] = 'AffectNet+'

# Combine existing and new datasets into a single table with dataset names and accuracy values
combined_table = pd.concat([
    ACC_df[['Datasets', 'Accuracy']],
    new_df.rename(columns={"Accuracy (%)": "Accuracy"})[['Datasets', 'Accuracy']]
], ignore_index=True)

# Save to a CSV file
combined_table.to_csv("combined_datasets_accuracy.csv", index=False)

# Display the combined table
combined_table.head()
# Out:
#   Datasets  Accuracy
# 0      CK+     94.40
# 1      CK+     96.80
# 2      CK+     96.70
# 3      CK+     92.05
# 4      CK+     93.70

# %%
def plot_min_max_accuracy_with_styling(df, selected_datasets, save_path="min_max_accuracy_styled.pdf"):
    # Filter the DataFrame to include only the selected datasets
    df_filtered = df[df['Datasets'].isin(selected_datasets)]
    
    # Group by dataset and calculate min and max accuracy
    grouped = df_filtered.groupby('Datasets')['Accuracy'].agg(['min', 'max']).reset_index()
    
    # Plot the min-max accuracy for each dataset
    plt.figure(figsize=(10, 6))
    for index, row in grouped.iterrows():
        # Draw the min-max line
        plt.plot([row['min'], row['max']], [row['Datasets'], row['Datasets']], 
                 color='black', linewidth=2)
        
        # Draw circles for min and max points with black border and gray fill
        plt.scatter([row['min'], row['max']], [row['Datasets'], row['Datasets']], 
                    color='gray', edgecolor='black', s=100, zorder=3)
    
    # Add labels and styling

    
    plt.title("Min-Max Accuracy by Dataset")
    plt.xlabel("Accuracy (%)")
    plt.ylabel("Datasets")
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save to PDF
    plt.savefig(save_path, format='pdf', dpi=300, bbox_inches='tight')
    plt.show()

# Example usage
selected_datasets = ['CK+', 'JAFFE', 'FER 2013', 'AffectNet+']
plot_min_max_accuracy_with_styling(combined_table, selected_datasets, save_path="min_max_accuracy_styled.pdf")
